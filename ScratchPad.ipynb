# %%
import numpy as np
from os import listdir
from os.path import isfile, join
import os
from glob import glob

# %%
import os.path
os.path.isfile('ScratchPad.ipynb')
# Out:
# True

# %%
import os
result = []
for root, dirs, files in os.walk(dir_path):
    for file in files:
        if file.endswith('.png') or file.endswith('.jpg') or file.endswith('.jpeg'):
             result.append(os.path.join(root, file))
print(result)
# Out:
# ['/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27082.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27083.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27084.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27085.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27086.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27087.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27088.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27089.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27090.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27091.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27092.png', '/Users/jkwok/Documents/Insig
# ...

# %%
dir_path = '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/noaa-20170903-rgb/16'
dir_path = '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16'

ext = '*.png'

result = [y for x in os.walk(dir_path) for y in glob(os.path.join(x[0], ext))]

print(result)
# Out:
# ['/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27082.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27083.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27084.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27085.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27086.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27087.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27088.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27089.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27090.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27091.png', '/Users/jkwok/Documents/Insight/tools/jTileDownloader 2/mapbox-sat/16/15360/27092.png', '/Users/jkwok/Documents/Insig
# ...
